# %%
# SPDX-License-Identifier: GPL-2.0-only
# Copyright © Interactive Echoes. All rights reserved.
# Author: mozahzah

import sys
sys.path.append('../DSPy')
import oscillator as osc
import filter as flt

sampleRate = 48000
oscFrequency = 4
amplitude = 6

oscillator_instance = osc.oscillator(sampleRate)

timeSecond = 1
signal = oscillator_instance.make_sine_signal(oscFrequency, amplitude, 0, timeSecond, False)

bufferSize = 512
oscillator_instance.draw_oscillator_signal(signal, bufferSize)

filter_instance = flt.filter(sampleRate, bufferSize*6)
filteredSignal = filter_instance.get_running_mean_filtered_signal(signal)

filter_instance.draw_filtered_signal(filteredSignal)
